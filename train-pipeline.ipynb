# %% [markdown]
# # Train part

# %% [markdown]
# ## add-ons -> secrets ->activate HF_TOKEN

# %% [markdown]
# ## Installation preparations

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("HF_TOKEN")
import os
os.environ["PATH"] = "/root/.local/bin:" + os.environ["PATH"]
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1" # magic downloads https://huggingface.co/docs/hub/models-downloading
os.environ["DSP_CACHEBOOL"] = "False" # for quick dev

# %%
# %%capture here
# !curl -LsSf https://astral.sh/uv/install.sh | sh

# %%
# %%capture here
# !uv pip install scikit-learn --system

# %%
# %%capture here
# !uv pip uninstall torch torchvision torchaudio --system
# !uv pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --system

# %%
# %%capture here
# !uv pip install proto-plus==1.24.0.dev1 dataset --system
# !uv pip install --upgrade datasets --system
# !uv pip install vllm --system

# %%
# %%capture here
# !uv pip install "huggingface_hub[hf_transfer]" --system
# !uv pip install dspy==2.5.34 datasets bitsandbytes triton hf_transfer --system # vllm

# %% [markdown]
# # Dataset prep

# %%
# !uv pip install pandas --system

# %%
import pandas as pd
import json
import re
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/kaggle/input/train-csv/train.csv",encoding='UTF-8',index_col=False)

# %%
STOP_WORDS = {
    # Prepositions
     'під', 'над', 'зі', 'біля',
    'для', 'між', 'перед', 'після', 'без', 'крізь',
    # Conjunctions
    'але', 'проте', 'однак', 'чи', 'якщо', 'коли',
    'щоб', 'бо', 'тому що', 'оскільки',
    # Articles and particles
    'же', 'би', 'б', 'хіба', 'невже',
    #additional
    'що','...'
}
def decode_entities(json_str):
    return json.loads(json_str)


def clean_text(text):
    # Replace all newline characters with a single space
    cleaned_text = re.sub(r'\n\n', ' ', text)
    cleaned_text = re.sub(r'\n', ' ', cleaned_text)
    # Remove commas and em dashes, replacing them with a single space
    cleaned_text = re.sub(r'[,—]', ' ', cleaned_text)
    # Replace consecutive spaces with a single space, iteratively
    cleaned_text = re.sub(r' {2,}', ' ', cleaned_text)
    return cleaned_text

# %%
# decoding of /u000 and saving as [{'MISC': 'КСВ'},...]
df["entities"] = (
    df["entities"]
    .apply(decode_entities)
    .apply(lambda entities: [{d["label"]: d["text"]} for d in entities])
)
df["text"] = df["text"].apply(clean_text)

# %%
def split_text_into_sentences(text):
    # Split text into sentences using regular expressions
    sentences = re.split(r'(?<=[.!?])\s*', text)  # Split by period, exclamation, or question mark
    return [s.strip() for s in sentences if s.strip()]  # Remove empty strings

def chunk_sentences(sentences, chunk_size, max_length):
    chunks = []
    current_chunk = []
    current_length = 0

    for sentence in sentences:
        sentence_length = len(sentence)
        # Check if adding the current sentence exceeds the chunk size or max length
        if len(current_chunk) < chunk_size and (current_length + sentence_length) <= max_length:
            current_chunk.append(sentence)
            current_length += sentence_length
        else:
            # Finalize the current chunk and start a new one
            if current_chunk:
                chunks.append(current_chunk)
            current_chunk = [sentence]
            current_length = sentence_length

    # Add the last chunk if it contains any sentences
    if current_chunk:
        chunks.append(current_chunk)

    return chunks

def process_dataframe(df, chunk_size, max_length):
    # Apply splitting and chunking to the specified column of the DataFrame
    df['split_text'] = df['text'].apply(
        lambda text: chunk_sentences(split_text_into_sentences(text), chunk_size, max_length)
    )
    return df

df = pd.DataFrame(df)
chunk_size = 6  # Number of sentences per chunk
max_length = 600  # Maximum character length per chunk

# Process the DataFrame
df = process_dataframe(df, chunk_size, max_length)

# %%
# Flatten the dataframe: each chunk of sentences becomes a new row, rest of columns are duplicated
expanded_df = df.explode('split_text', ignore_index=True)

# %%
expanded_df=expanded_df[['id','split_text','entities']]

# %%
# expanded_df.columns

# %%
# for i in expanded_df['split_text']:
#     print()
#     print(i)

# %%
# len(expanded_df)

# %%
# drop ['']
expanded_df = expanded_df[expanded_df['split_text'].apply(lambda x: x != [''])]

# %%
def filter_entities_based_on_text(split_text, entities):
    # Combine all split text pieces into one string and convert to lowercase
    combined_text = ' '.join(split_text).lower()
    
    # Initialize list for filtered entities
    filtered_entities = []
    
    # Create a dictionary to track occurrences of each entity
    entity_counts = {}
    
    # First pass: count occurrences of each unique entity in the text
    for entity in entities:
        for entity_type, value in entity.items():
            value_lower = value.lower()
            # Count actual occurrences in text
            count = combined_text.count(value_lower)
            if count > 0:
                entity_id = f"{entity_type}_{value_lower}"
                entity_counts[entity_id] = count
    
    # Second pass: add entities the correct number of times
    for entity in entities:
        for entity_type, value in entity.items():
            value_lower = value.lower()
            entity_id = f"{entity_type}_{value_lower}"
            
            # If we still have occurrences to account for
            if entity_id in entity_counts and entity_counts[entity_id] > 0:
                filtered_entities.append(entity)
                entity_counts[entity_id] -= 1
    
    return filtered_entities

# Apply the filter function to the DataFrame
expanded_df['filtered_entities'] = expanded_df.apply(
    lambda row: filter_entities_based_on_text(row['split_text'], row['entities']), 
    axis=1
)

# %%
# tokenize right here (just in case)
# Define a function to tokenize and flatten the list of sentences into a single list of tokens
def tokenize_text(text_list):
    # Regex to match words, handling special characters
    tokenized_list = [re.findall(r'\S+|\n', text) for text in text_list]
    # Flatten the list of lists into a single list
    return [token for sublist in tokenized_list for token in sublist]

# Apply this function to the 'split_text' column
expanded_df['tokenized_text'] = expanded_df['split_text'].apply(tokenize_text)

# %%
# Splitting the dataset
X_train, X_test = train_test_split(expanded_df, test_size=0.3, random_state=42)
X_train=X_train[['id','tokenized_text','filtered_entities']]
X_test=X_test[['id','tokenized_text','filtered_entities']]

# %% [markdown]
# # Model part

# %% [markdown]
# ## Installation and  setup

# %%
os.environ["PATH"] = "/root/.local/bin:" + os.environ["PATH"]
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
# %%capture here
# !uv pip install ollama --system

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("HF_TOKEN")
import dspy
import pandas as pd
import ollama
os.environ["HF_TOKEN"] = secret_value_0
import subprocess
import time

# %%
# %%capture here
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
# %%capture here
# !ollama pull gemma2:9b-instruct-fp16 # 8 хв чекаєм
# Out:
# [GIN] 2024/12/13 - 20:11:56 | 200 |      57.186µs |       127.0.0.1 | HEAD     "/"
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manif
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest ⠋ [GIN] 2024/12/13 - 20:14:24 | 200 |         2m28s |       127.0.0.1 | POST     "/api/pull"
# pulling manifest
# pulling 76c95736fd14... 100% ▕████████████████▏  18 GB
# pulling 109037bec39c... 100% ▕████████████████▏  136 B
# pulling 097a36493f71... 100% ▕████████████████▏ 8.4 KB
# pulling 2490e7468436... 100% ▕████████████████▏   65 B
# pulling 6c29221808fb... 100% ▕████████████████▏  486 B
# verifying sha256 digest
# writing manifest
# success

# %%
time.sleep(60*8)

# %% [markdown]
# ## Model predict part

# %%
# %%capture here
process = subprocess.Popen("ollama serve", shell=True) #runs on a different thread #add "--tensor_parallel_size", "2",
# Out:
# Error: listen tcp 127.0.0.1:11434: bind: address already in use

# %%
lm = dspy.LM('ollama_chat/gemma2:9b-instruct-fp16', api_base='http://localhost:11434', api_key='')
dspy.configure(lm=lm)

# %%
# Convert DataFrame rows into dspy.Example objects
def create_examples(dataset):
    examples = [
        dspy.Example(
            # id = row["id"],
            tokens=row["tokenized_text"],
            expected_entities=row["filtered_entities"]
        ).with_inputs("tokenized_text")
        for _, row in dataset.iterrows()
    ]
    return examples

# Example usage with different datasets
train = create_examples(X_train[:100]) # 100 samples#############
test = create_examples(X_test[:33]) # 33 samples ################

# %%
class Expert_Linguist(dspy.Signature):
    """EXTRACT ENTITIES:
    LEAVE THE WORD ENDINGS OR DECLENSIONS OF ANY ENTITY AS IS!!!.
    JOB: roles/positions
    PERS: names
    ORG: organizations
    LOC: locations
    ART: artifacts
    DATE: dates
    TIME: times
    PERIOD: durations
    MONEY: amounts
    PCT: percentages
    QUANT: quantities
    MISC: other named
    DOC: documents
    - LEAVE THE WORD ENDINGS OR DECLENSIONS OF ANY ENTITY AS IS!!!. 
      The original form of the entity (with correct case, gender, and declension) should remain intact.
    - Value for "JOB" e.g. can be "фахівець із IT"
    - Value for "LOC" e.g. can be "Чернівців"
    - Value for "ART" e.g. can be "Різдвяна історія з Тіною Кароль"
    - Value for "ART" e.g. can be "олешківської міськрайонки"
    - Value for "PERS" e.g. can be "Іван Підгорський").
    - RETURN empty list IF THERE IS NO ENTITIES"""
    tokens=dspy.InputField()
    entities =dspy.OutputField(desc="List[Dict[str, str]]. like so [{'JOB':'entity entity entity'}, {'ORG':'entity entity'}, {'MONEY':'entity'}] LEAVE THE WORD ENDINGS OR DECLENSIONS OF ANY ENTITY AS IS!!!.")

# %%
just_extractor = dspy.ChainOfThought(Expert_Linguist)

# %%
df2=X_train[['id', 'tokenized_text', 'filtered_entities']]

# %%
# %%capture
start = 1       # Початковий індекс
batch_size = 2# # Розмір слайсу 1385 

result=pd.DataFrame(
    [
        {"id":row["id"],
         "entities": just_extractor(tokens=dspy.Example(tokens=row["tokenized_text"])).entities
        } for _, row in df2.iloc[start:start+batch_size].iterrows()
    ])
# Out:
# 20:52:13 - LiteLLM:INFO: utils.py:2749 -
# LiteLLM completion() model= gemma2:9b-instruct-fp16; provider = ollama_chat
# time=2024-12-13T20:52:13.970Z level=INFO source=sched.go:730 msg="new model will fit in available VRAM, loading" model=/root/.ollama/models/blobs/sha256-76c95736fd1483b32c8ad704594349e92fa3ec947c8fea45942caa5bd28df08d library=cuda parallel=4 required="24.0 GiB"
# time=2024-12-13T20:52:14.178Z level=INFO source=server.go:105 msg="system memory" total="31.4 GiB" free="29.4 GiB" free_swap="0 B"
# time=2024-12-13T20:52:14.179Z level=INFO source=memory.go:356 msg="offload to cuda" layers.requested=-1 layers.model=43 layers.offload=43 layers.split=22,21 memory.available="[14.6 GiB 14.6 GiB]" memory.gpu_overhead="0 B" memory.required.full="24.0 GiB" memory.required.partial="24.0 GiB" memory.required.kv="2.6 GiB" memory.required.allocations="[12.8 GiB 11.1 GiB]" memory.weights.total="18.1 GiB" memory.weights.repeating="16.4 GiB" memory.weights.nonrepeating="1.7 GiB" memory.graph.full="1.2 GiB" memory.graph.partial="1.2 GiB"
# time=2024-12-13T20:52:14.200Z level=INFO source=server.go:397 msg="starting llama server" cmd="/tmp/ollama3322654689/runners/cuda_v12/ollama_llama_server --model /root/.ollama/models/blobs/sha256-76c95736fd1483b32c8ad704594349e92fa3ec947c8fea45942caa5bd28df08d --ctx-size 8192 --batch-size 512 --n-gpu-layers 43 --threads 2 --parallel 4 --tensor-split 22,21 --port 39529"
# time=2024-12-13T20:52:14.200Z level=INFO source=sched.go:449 msg="loaded runners" count=1
# time=2024-12-13T20:52:14.200Z level=INFO source=server.go:576 msg="waiting for llama runner to start responding"
# time=2024-12-13T20:52:14.203Z level=INFO source=server.go:610 msg="waiting for server to become available" status="llm server error"
# time=2024-12-13T20:52:14.523Z level=INFO source=runner.go:941 msg="starting go runner"
# time=2024-12-13T20:52:14.524Z level=INFO source=runner.go:942 msg=system info="AVX = 1 | AVX_VNNI = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | AVX512_BF16 = 0 | FMA = 0 | NEON = 0 | SVE = 0 | ARM_FMA = 0 | F16C = 0 | FP16_VA = 0 | RISCV_VECT = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 | MATMUL_INT8 = 0 | LLAMAFILE = 1 | cgo(gcc)" threads=2
# time=2024-12-13T20:52:14.524Z level=INFO source=.:0 msg="Server listening on 127.0.0.1:39529"
# llama_model_loader: loaded meta data with 29 key-value pairs and 464 tensors from /root/.ollama/models/blobs/sha256-76c95736fd1483b32c8ad704594349e92fa3ec947c8fea45942caa5bd28df08d (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma2
# llama_model_loader: - kv   1:                               general.name str              = gemma-2-9b-it
# llama_model_loader: - kv   2:                      gemma2.context_length u32              = 8192
# llama_model_loader: - kv   3:                    gemma2.embedding_length u32              = 3584
# llama_model_loader: - kv   4:                         gemma2.block_count u32              = 42
# llama_model_loader: - kv   5:                 gemma2.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                gemma2.attention.head_count u32              = 16
# llama_model_loader: - kv   7:             gemma2.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   8:    gemma2.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv   9:                gemma2.attention.key_length u32              = 256
# llama_model_loader: - kv  10:              gemma2.attention.value_length u32              = 256
# llama_model_loader: - kv  11:                          general.file_type u32              = 1
# llama_model_loader: - kv  12:              gemma2.attn_logit_softcapping f32              = 50.000000
# llama_model_loader: - kv  13:             gemma2.final_logit_softcapping f32              = 30.000000
# llama_model_loader: - kv  14:            gemma2.attention.sliding_window u32              = 4096
# llama_model_loader: - kv  15:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  16:                         tokenizer.ggml.pre str              = default
# llama_model_loader: - kv  17:                      tokenizer.ggml.tokens arr[str,256000]  = ["<pad>", "<eos>", "<bos>", "<unk>", ...
# time=2024-12-13T20:52:14.705Z level=INFO source=server.go:610 msg="waiting for server to become available" status="llm server loading model"
# llama_model_loader: - kv  18:                      tokenizer.ggml.scores arr[f32,256000]  = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  19:                  tokenizer.ggml.token_type arr[i32,256000]  = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  20:                tokenizer.ggml.bos_token_id u32              = 2
# llama_model_loader: - kv  21:                tokenizer.ggml.eos_token_id u32              = 1
# llama_model_loader: - kv  22:            tokenizer.ggml.unknown_token_id u32              = 3
# llama_model_loader: - kv  23:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  24:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  25:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  26:                    tokenizer.chat_template str              = {{ bos_token }}{% if messages[0]['rol...
# llama_model_loader: - kv  27:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  28:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:  169 tensors
# llama_model_loader: - type  f16:  295 tensors
# llm_load_vocab: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# llm_load_vocab: special tokens cache size = 108
# llm_load_vocab: token to piece cache size = 1.6014 MB
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = gemma2
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 256000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: vocab_only       = 0
# llm_load_print_meta: n_ctx_train      = 8192
# llm_load_print_meta: n_embd           = 3584
# llm_load_print_meta: n_layer          = 42
# llm_load_print_meta: n_head           = 16
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_rot            = 256
# llm_load_print_meta: n_swa            = 4096
# llm_load_print_meta: n_embd_head_k    = 256
# llm_load_print_meta: n_embd_head_v    = 256
# llm_load_print_meta: n_gqa            = 2
# llm_load_print_meta: n_embd_k_gqa     = 2048
# llm_load_print_meta: n_embd_v_gqa     = 2048
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-06
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: f_logit_scale    = 0.0e+00
# llm_load_print_meta: n_ff             = 14336
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: causal attn      = 1
# llm_load_print_meta: pooling type     = 0
# llm_load_print_meta: rope type        = 2
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_ctx_orig_yarn  = 8192
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: ssm_d_conv       = 0
# llm_load_print_meta: ssm_d_inner      = 0
# llm_load_print_meta: ssm_d_state      = 0
# llm_load_print_meta: ssm_dt_rank      = 0
# llm_load_print_meta: ssm_dt_b_c_rms   = 0
# llm_load_print_meta: model type       = 9B
# llm_load_print_meta: model ftype      = F16
# llm_load_print_meta: model params     = 9.24 B
# llm_load_print_meta: model size       = 17.22 GiB (16.00 BPW)
# llm_load_print_meta: general.name     = gemma-2-9b-it
# llm_load_print_meta: BOS token        = 2 '<bos>'
# llm_load_print_meta: EOS token        = 1 '<eos>'
# llm_load_print_meta: UNK token        = 3 '<unk>'
# llm_load_print_meta: PAD token        = 0 '<pad>'
# llm_load_print_meta: LF token         = 227 '<0x0A>'
# llm_load_print_meta: EOT token        = 107 '<end_of_turn>'
# llm_load_print_meta: EOG token        = 1 '<eos>'
# llm_load_print_meta: EOG token        = 107 '<end_of_turn>'
# llm_load_print_meta: max token length = 93
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    no
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 2 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5, VMM: yes
#   Device 1: Tesla T4, compute capability 7.5, VMM: yes
# llm_load_tensors: ggml ctx size =    0.62 MiB
# llm_load_tensors: offloading 42 repeating layers to GPU
# llm_load_tensors: offloading non-repeating layers to GPU
# llm_load_tensors: offloaded 43/43 layers to GPU
# llm_load_tensors:        CPU buffer size =  1750.00 MiB
# llm_load_tensors:      CUDA0 buffer size =  8317.20 MiB
# llm_load_tensors:      CUDA1 buffer size =  9311.11 MiB
# llama_new_context_with_model: n_ctx      = 8192
# llama_new_context_with_model: n_batch    = 2048
# llama_new_context_with_model: n_ubatch   = 512
# llama_new_context_with_model: flash_attn = 0
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_kv_cache_init:      CUDA0 KV buffer size =  1408.00 MiB
# llama_kv_cache_init:      CUDA1 KV buffer size =  1280.00 MiB
# llama_new_context_with_model: KV self size  = 2688.00 MiB, K (f16): 1344.00 MiB, V (f16): 1344.00 MiB
# llama_new_context_with_model:  CUDA_Host  output buffer size =     3.96 MiB
# llama_new_context_with_model: pipeline parallelism enabled (n_copies=4)
# llama_new_context_with_model:      CUDA0 compute buffer size =   442.01 MiB
# llama_new_context_with_model:      CUDA1 compute buffer size =   663.02 MiB
# llama_new_context_with_model:  CUDA_Host compute buffer size =   135.02 MiB
# llama_new_context_with_model: graph nodes  = 1690
# llama_new_context_with_model: graph splits = 3
# time=2024-12-13T20:52:25.245Z level=INFO source=server.go:615 msg="llama runner started in 11.04 seconds"
# llama_model_loader: loaded meta data with 29 key-value pairs and 464 tensors from /root/.ollama/models/blobs/sha256-76c95736fd1483b32c8ad704594349e92fa3ec947c8fea45942caa5bd28df08d (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma2
# llama_model_loader: - kv   1:                               general.name str              = gemma-2-9b-it
# llama_model_loader: - kv   2:                      gemma2.context_length u32              = 8192
# llama_model_loader: - kv   3:                    gemma2.embedding_length u32              = 3584
# llama_model_loader: - kv   4:                         gemma2.block_count u32              = 42
# llama_model_loader: - kv   5:                 gemma2.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                gemma2.attention.head_count u32              = 16
# llama_model_loader: - kv   7:             gemma2.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   8:    gemma2.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv   9:                gemma2.attention.key_length u32              = 256
# llama_model_loader: - kv  10:              gemma2.attention.value_length u32              = 256
# llama_model_loader: - kv  11:                          general.file_type u32              = 1
# llama_model_loader: - kv  12:              gemma2.attn_logit_softcapping f32              = 50.000000
# llama_model_loader: - kv  13:             gemma2.final_logit_softcapping f32              = 30.000000
# llama_model_loader: - kv  14:            gemma2.attention.sliding_window u32              = 4096
# llama_model_loader: - kv  15:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  16:                         tokenizer.ggml.pre str              = default
# llama_model_loader: - kv  17:                      tokenizer.ggml.tokens arr[str,256000]  = ["<pad>", "<eos>", "<bos>", "<unk>", ...
# llama_model_loader: - kv  18:                      tokenizer.ggml.scores arr[f32,256000]  = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  19:                  tokenizer.ggml.token_type arr[i32,256000]  = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  20:                tokenizer.ggml.bos_token_id u32              = 2
# llama_model_loader: - kv  21:                tokenizer.ggml.eos_token_id u32              = 1
# llama_model_loader: - kv  22:            tokenizer.ggml.unknown_token_id u32              = 3
# llama_model_loader: - kv  23:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  24:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  25:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  26:                    tokenizer.chat_template str              = {{ bos_token }}{% if messages[0]['rol...
# llama_model_loader: - kv  27:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  28:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:  169 tensors
# llama_model_loader: - type  f16:  295 tensors
# llm_load_vocab: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# llm_load_vocab: special tokens cache size = 108
# llm_load_vocab: token to piece cache size = 1.6014 MB
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = gemma2
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 256000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: vocab_only       = 1
# llm_load_print_meta: model type       = ?B
# llm_load_print_meta: model ftype      = all F32
# llm_load_print_meta: model params     = 9.24 B
# llm_load_print_meta: model size       = 17.22 GiB (16.00 BPW)
# llm_load_print_meta: general.name     = gemma-2-9b-it
# llm_load_print_meta: BOS token        = 2 '<bos>'
# llm_load_print_meta: EOS token        = 1 '<eos>'
# llm_load_print_meta: UNK token        = 3 '<unk>'
# llm_load_print_meta: PAD token        = 0 '<pad>'
# llm_load_print_meta: LF token         = 227 '<0x0A>'
# llm_load_print_meta: EOT token        = 107 '<end_of_turn>'
# llm_load_print_meta: EOG token        = 1 '<eos>'
# llm_load_print_meta: EOG token        = 107 '<end_of_turn>'
# llm_load_print_meta: max token length = 93
# llama_model_load: vocab only - skipping tensors
# 20:52:36 - LiteLLM:INFO: utils.py:944 - Wrapper: Completed Call, calling success_handler
# 20:52:36 - LiteLLM:INFO: utils.py:2749 -
# LiteLLM completion() model= gemma2:9b-instruct-fp16; provider = ollama_chat
# [GIN] 2024/12/13 - 20:52:36 | 200 | 22.990841169s |       127.0.0.1 | POST     "/api/chat"
# [GIN] 2024/12/13 - 20:52:36 | 404 |      111.42µs |       127.0.0.1 | POST     "/api/show"
# 20:52:58 - LiteLLM:INFO: utils.py:944 - Wrapper: Completed Call, calling success_handler
# [GIN] 2024/12/13 - 20:52:58 | 200 | 21.829069719s |       127.0.0.1 | POST     "/api/chat"
# [GIN] 2024/12/13 - 20:52:58 | 404 |     125.062µs |       127.0.0.1 | POST     "/api/show"

# %%
for i in result.entities:
    print()
    print(i)
# Out:
# [{'PERS': 'Ілія'}, {'ART': 'замок'}, {'ART': 'золото'}, {'ART': 'безсмертя'}]
#
# [{'JOB': 'фахівець із IT'}, {'ORG': 'ДП «Шахтоуправління «Південнодонбаське №1»'}, {'ORG': 'ТОВ «Компанія Промторг»'}, {'ORG': '«Вісник державних закупівель»'}, {'ORG': "«Об'єднана компанія «Укрвуглереструктуризація»"}, {'ART': 'ШСС-1П'}, {'MONEY': '13 34 млн грн.'}, {'MONEY': '7408 грн.'}, {'MONEY': '6734 грн.'}, {'DATE': 'лютого'}, {'DATE': '20156 року'}, {'TIME': 'листопаді'}, {'TIME': 'минулого року'}]

# %% [markdown]
# # THE END

# %%
# def extraction_correctness_metric(example: dspy.Example, prediction: dspy.Prediction, trace=None) -> bool:
#     """
#     Computes correctness of entity extraction predictions.
    
#     Args:
#         example (dspy.Example): The dataset example containing expected people entities.
#         prediction (dspy.Prediction): The prediction from the DSPy people extraction program.
#         trace: Optional trace object for debugging.
    
#     Returns:
#         bool: True if predictions match expectations, False otherwise.
#     """
#     return prediction.entities == example.expected_entities

# evaluate_correctness = dspy.Evaluate(
#     devset=test,
#     metric=extraction_correctness_metric,
#     num_threads= 48,# 24
#     display_progress=True,
#     display_table=True
# )

# %%
# evaluate_correctness(Expert_Linguist, devset=test)
# Out:
# 2024/12/13 20:46:42 ERROR dspy.utils.parallelizer: Error processing item Example({'tokens': ['Цей', 'фактор', 'звичайно', 'важливий', 'проте', 'такий', 'вибір', 'не', 'завжди', 'може', 'бути', 'найвигіднішим', '.', 'Для', 'того', 'щоби', 'зробити', 'оптимальний', 'вибір', 'варто', 'звернути', 'увагу', 'на', 'такі', 'нюанси', '.', 'Щорічно', 'Пенсійний', 'Фонд', 'визначає', 'перелік', 'банків', 'які', 'можуть', 'надавати', 'послуги', 'з', 'виплати', 'пенсій', '.', 'Теоретично', 'Пенсійний', 'Фонд', 'вибирає', 'для', 'співпраці', 'надійні', 'банки', 'з', 'хорошими', 'фінансовими', 'показниками', '.'], 'expected_entities': [{'ORG': 'Пенсійний Фонд'}, {'ORG': 'Пенсійний Фонд'}]}) (input_keys={'tokenized_text'}): 2 validation errors for Expert_Linguist
# tokens
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# entities
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing. Set `provide_traceback=True` to see the stack trace.
# 2024/12/13 20:46:42 ERROR dspy.utils.parallelizer: Error processing item Example({'tokens': ['Матеріали', 'ревізії', 'передано', 'до', 'правоохоронних', 'органів.', '_Від', '«Наших', 'Грошей»:', '_', 'Згідно', 'з', 'останніми', 'даними', 'SMIDA', 'основний', 'пакет', 'акцій', 'фірми', '«Укрінстрах»', 'у', 'розмірі', '99', '78%', 'має', 'одна', 'фізособа', "ім'я", 'котрої', 'не', 'розкривається', 'оскільки', 'вона', 'не', 'надала', 'дозволу', 'на', 'оприлюднення', 'персональних', 'даних.', 'Директором', 'підприємства', 'є', 'Юлія', 'Вержанська', 'Наглядову', 'раду', 'підприємства', 'очолює', 'Володимир', 'Нечай.', 'Фірма', 'зареєстрована', 'в', 'Івано-Франківську', 'за', 'адресою', 'вул.', 'Промислова', 'буд.', '29.'], 'expected_entities': [{'ORG': 'ДП'}, {'ART': 'Наших Грошей'}, {'ORG': 'SMIDA'}, {'ORG': 'Укрінстрах'}, {'JOB': 'Директором'}, {'PERS': 'Юлія Вержанська'}, {'PERS': 'Володимир Нечай'}, {'LOC': 'Івано-Франківську'}]}) (input_keys={'tokenized_text'}): 2 validation errors for Expert_Linguist
# tokens
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# entities
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing. Set `provide_traceback=True` to see the stack trace.
# 2024/12/13 20:46:42 ERROR dspy.utils.parallelizer: Error processing item Example({'tokens': ['Кожний', 'образ', 'у', 'якому', 'поставала', 'Тіна', 'Кароль', '–', 'справжній', 'витвір', 'мистецтва', '.', 'Довершений', 'і', 'бездоганний', '.', 'Зі', 'стовідсотковим', 'улученням', 'у', 'контекст', 'композиції', '.', 'Тіна', 'Кароль', 'настільки', 'точна', 'й', 'органічна', 'в', 'цьому', 'фільмі', 'що', 'якоїсь', 'критики', 'навіть', 'не', 'заслуговує', '.', '«', 'Щедрик', '»', 'у', 'Софійському', 'соборі', 'на', 'тлі', 'грізної', 'Оранти-захисниці', '–', 'просто', 'шедевр', 'із', 'усіх', 'поглядів', '.', 'Музичного', 'виконавського', 'сценічного', '…', 'Джазове', 'аранжування', 'найвідомішої', 'в', 'світі', 'колядки', 'в', 'обробці', 'Миколи', 'Леонтовича', 'продемонструвало', 'невичерпність', 'цієї', 'мелодії', 'для', 'інтерпретацій', '.'], 'expected_entities': [{'PERS': 'Тіна Кароль'}, {'PERS': 'Тіна Кароль'}, {'ART': 'Щедрик'}, {'LOC': 'Софійському соборі'}, {'PERS': 'Оранти-захисниці'}, {'PERS': 'Миколи Леонтовича'}, {'PERS': 'Тіна'}]}) (input_keys={'tokenized_text'}): 2 validation errors for Expert_Linguist
# tokens
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# entities
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing. Set `provide_traceback=True` to see the stack trace.
# 2024/12/13 20:46:42 ERROR dspy.utils.parallelizer: Error processing item Example({'tokens': ['Лише', 'наважитись', '.', '.', 'Так', 'як', 'міг', 'Лі', 'Бо', '.', '.', 'Я', 'в', 'поїзді', '.', 'Сьогодні', 'Покрова', 'і', 'якраз', 'уночі', 'випав', 'сніг', '.'], 'expected_entities': [{'PERS': 'Лі Бо'}, {'MISC': 'Покрова'}]}) (input_keys={'tokenized_text'}): 2 validation errors for Expert_Linguist
# tokens
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# entities
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing. Set `provide_traceback=True` to see the stack trace.
#   0%|          | 0/33 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 evaluate_correctness(Expert_Linguist, devset=test)
#
# File /opt/conda/lib/python3.10/site-packages/dspy/evaluate/evaluate.py:112, in Evaluate.__call__(self, program, metric, devset, num_threads, display_progress, display_table, return_all_scores, return_outputs)
#     108         program._suggest_failures += dspy.settings.get("suggest_failures")
#     110     return prediction, score
# --> 112 results = executor.execute(process_item, devset)
#     113 assert len(devset) == len(results)
#     115 results = [((dspy.Prediction(), self.failure_score) if r is None else r) for r in results]
#
# File /opt/conda/lib/python3.10/site-packages/dspy/utils/parallelizer.py:42, in ParallelExecutor.execute(self, function, data)
#      40     return self._execute_single_thread(wrapped_function, data)
#      41 else:
# ---> 42     return self._execute_multi_thread(wrapped_function, data)
#
# File /opt/conda/lib/python3.10/site-packages/dspy/utils/parallelizer.py:164, in ParallelExecutor._execute_multi_thread(self, function, data)
#     156 pbar = tqdm.tqdm(
#     157     total=len(data),
#     158     dynamic_ncols=True,
#     159     disable=self.disable_progress_bar,
#     160     file=sys.stdout,
#     161 )
#     163 for future in as_completed(futures):
# --> 164     index, result = future.result()
#     166     if result is job_cancelled:
#     167         continue
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/lib/python3.10/site-packages/dspy/utils/parallelizer.py:150, in ParallelExecutor._execute_multi_thread.<locals>.cancellable_function(index_item, parent_id)
#     148 if self.cancel_jobs.is_set():
#     149     return index, job_cancelled
# --> 150 return index, function(item, parent_id)
#
# File /opt/conda/lib/python3.10/site-packages/dspy/utils/parallelizer.py:72, in ParallelExecutor._wrap_function.<locals>.wrapped(item, parent_id)
#      70 if current_error_count >= self.max_errors:
#      71     self.cancel_jobs.set()
# ---> 72     raise e
#      73 if self.provide_traceback:
#      74     logger.error(
#      75         f"Error processing item {item}: {e}\nStack trace:\n{traceback.format_exc()}"
#      76     )
#
# File /opt/conda/lib/python3.10/site-packages/dspy/utils/parallelizer.py:65, in ParallelExecutor._wrap_function.<locals>.wrapped(item, parent_id)
#      61     # TODO: Consider the behavior below.
#      62     # import copy; thread_stacks[current_thread_id].append(copy.deepcopy(thread_stacks[current_thread_id][-1]))
#      64 try:
# ---> 65     return function(item)
#      66 except Exception as e:
#      67     with self.error_lock:
#
# File /opt/conda/lib/python3.10/site-packages/dspy/evaluate/evaluate.py:101, in Evaluate.__call__.<locals>.process_item(example)
#     100 def process_item(example):
# --> 101     prediction = program(**example.inputs())
#     102     score = metric(example, prediction)
#     104     # Increment assert and suggest failures to program's attributes
#
# File /opt/conda/lib/python3.10/site-packages/dspy/signatures/signature.py:38, in SignatureMeta.__call__(cls, *args, **kwargs)
#      36 if cls is Signature:
#      37     return make_signature(*args, **kwargs)
# ---> 38 return super().__call__(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pydantic/main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 2 validation errors for Expert_Linguist
# tokens
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# entities
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing

# %%
# mipro_optimizer = dspy.MIPROv2(
#     metric=extraction_correctness_metric,
    
# num_candidates= 2 #default
#     #auto="medium",
# )
# optimized_people_extractor = mipro_optimizer.compile(
#     Expert_Linguist,
#     trainset=train,
#     max_bootstrapped_demos=2,#4
#     num_trials=1,#default
#     requires_permission_to_run=False,
#     minibatch=True,
# )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 7
#       1 mipro_optimizer = dspy.MIPROv2(
#       2     metric=extraction_correctness_metric,
#       3
#       4 num_candidates= 2 #default
#       5     #auto="medium",
#       6 )
# ----> 7 optimized_people_extractor = mipro_optimizer.compile(
#       8     Expert_Linguist,
#       9     trainset=train,
#      10     max_bootstrapped_demos=2,#4
#      11     num_trials=1,#default
#      12     requires_permission_to_run=False,
#      13     minibatch=True,
#      14 )
#
# File /opt/conda/lib/python3.10/site-packages/dspy/teleprompt/mipro_optimizer_v2.py:139, in MIPROv2.compile(self, student, trainset, teacher, valset, num_trials, max_bootstrapped_demos, max_labeled_demos, seed, minibatch, minibatch_size, minibatch_full_eval_steps, program_aware_proposer, data_aware_proposer, view_data_batch_size, tip_aware_proposer, fewshot_aware_proposer, requires_permission_to_run)
#     136     self._print_auto_run_settings(num_trials, minibatch, valset)
#     138 if minibatch and minibatch_size > len(valset):
# --> 139     raise ValueError(
#     140         f"Minibatch size cannot exceed the size of the valset. Valset size: {len(valset)}."
#     141     )
#     143 # Estimate LM calls and get user confirmation
#     144 if requires_permission_to_run:
#
# ValueError: Minibatch size cannot exceed the size of the valset. Valset size: 8.

# %%
evaluate_correctness(Expert_Linguist, devset=X_test)

# %%
dspy.inspect_history(n=1)
